# %% [markdown]
# # 1) Clean Spotify Streaming History and MyLibrary CSV files

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import requests
import json
import os
import downloading_and_cleaning as dc
from dotenv import load_dotenv
load_dotenv()
client_ID = os.getenv("client_ID")
client_secret = os.getenv("client_secret")

# %% [markdown]
# ### Spotify provides the streaming history into two separeted CSV files that need merger.

# %%
stream0 = pd.read_json('data/Raw_Data/StreamingHistory0.json')
stream1 = pd.read_json('data/Raw_Data/StreamingHistory1.json')
df_stream = pd.concat([stream0, stream1])
df_stream['endTime'] = pd.to_datetime(df_stream['endTime'])
df_stream.sample(3)
# Out:
#                  endTime             artistName      trackName  msPlayed
# 1971 2021-05-29 21:44:00  Red Hot Chili Peppers      Porcelain    163457
# 241  2021-05-02 18:49:00              Colapesce         Totale      2043
# 2492 2021-06-06 14:33:00                 Rancid  Hoover Street    249733

# %% [markdown]
# #### Split time into multiple columns and transformed msPlayed (milisecs.) to minutes.

# %%
df_stream['year'] = pd.DatetimeIndex((df_stream.endTime)).year
df_stream['month'] = pd.DatetimeIndex((df_stream.endTime)).month
df_stream['day'] = pd.DatetimeIndex((df_stream.endTime)).day
df_stream['hour'] = pd.DatetimeIndex((df_stream.endTime)).hour
df_stream['minutesPlayed'] = round(df_stream['msPlayed']/60000,2)
df_stream.sample(3)
# Out:
#                  endTime                artistName            trackName  \
# 154  2021-05-01 17:13:00  Del The Funky Homosapien        Lyric Licking
# 1941 2020-12-07 19:43:00              Face To Face  Bent but Not Broken
# 4190 2021-02-03 22:38:00                  Lagwagon                Reign
#
#       msPlayed  year  month  day  hour  minutesPlayed
# 154      15418  2021      5    1    17           0.26
# 1941    150547  2020     12    7    19           2.51
# 4190      3552  2021      2    3    22           0.06

# %% [markdown]
# ### The key that will enable the iterations with  Spotify's API is contained in another file called "MyLibrary".
# #### The key name is "uri" and referes to the "track_id".

# %%
library0 = open('data/Raw_Data/YourLibrary.json')
library1 = json.load(library0)
df_library = pd.DataFrame(library1['tracks'])
df_library['uri'] = df_library.uri.str.split('spotify:track:', expand=True)[1]
df_library.sample(3)
# Out:
#            artist                album     track                     uri
# 685     Sugarcult   Punk Goes Acoustic    Memory  5GMOO1d22BsIvMmlhxUwrg
# 244  The Low Life         Daisy Cutter  Castaway  7G2qfNCNMxL4LYdNL3cWtF
# 577     Metronomy  The English Riviera   The Bay  3ySxo6vRP0t9WCqhYXXMWN

# %% [markdown]
# ### Merger of the StreamingHistory and MyLibrary to obtain the "Track_ID".
# #### This is the last step to finish cleaning the CSV files provided by Spotify.

# %%
df_stream = df_stream.merge(df_library, how='inner', 
                              left_on=['artistName', 'trackName'],
                              right_on=['artist', 'track'])

df_stream = df_stream[['endTime', 'year', 'month', 'day', 'hour', 'artist', 'album', 'track', 'minutesPlayed', 'uri']]
df_stream.sample(3)
# Out:
#                 endTime  year  month  day  hour       artist  \
# 131 2021-02-21 23:16:00  2021      2   21    23     The Cure
# 97  2020-10-31 20:17:00  2020     10   31    20  The Beatles
# 514 2021-09-07 18:04:00  2021      9    7    18       Coolio
#
#                                 album                                  track  \
# 131  Staring At The Sea - The Singles                         Boys Don't Cry
# 97                        Anthology 2   It's Only Love - Anthology 2 Version
# 514                  It Takes a Thief  Mama, I'm in Love Wit a Gangsta - Mix
#
#      minutesPlayed                     uri
# 131           2.59  1YQCRXscu8xE74BVVMUCRr
# 97            1.97  7EwuWi1xtmBLWYxWIyUj0r
# 514           1.17  62h3HmtlAmot4A9zwKVRSq

# %% [markdown]
# # 2) Connect to Spotify API

# %%
token , headers = dc.connect_api(client_ID, client_secret)

# %% [markdown]
# # 3) Iterate with the API

# %%
uris = list(df_library['uri'].unique())

# %%
df_features = dc.song_attributes('audio-features/', uris, headers)
df_features.head(3)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.632   0.471    0    -7.887     1       0.0348         0.313
# 1         0.875   0.481    1   -13.337     1       0.3120         0.134
# 2         0.712   0.676    9    -7.313     0       0.1530         0.191
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000005    0.0712    0.764  121.672  audio_features
# 1          0.001120    0.1320    0.836   85.021  audio_features
# 2          0.066500    0.1250    0.869   79.994  audio_features
#
#                        id                                   uri  \
# 0  5e8uc7f0v5jpY5SF1emxHl  spotify:track:5e8uc7f0v5jpY5SF1emxHl
# 1  62h3HmtlAmot4A9zwKVRSq  spotify:track:62h3HmtlAmot4A9zwKVRSq
# 2  0HmQkmfYXRPweIg1ycw1R8  spotify:track:0HmQkmfYXRPweIg1ycw1R8
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5e8uc7f0v5jp...
# 1  https://api.spotify.com/v1/tracks/62h3HmtlAmot...
# 2  https://api.spotify.com/v1/tracks/0HmQkmfYXRPw...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5e8u...       168120
# 1  https://api.spotify.com/v1/audio-analysis/62h3...       250160
# 2  https://api.spotify.com/v1/audio-analysis/0HmQ...       291440
#
#    time_signature
# 0               4
# 1               4
# 2               4

# %%
df_tracks = dc.song_attributes('tracks/', uris, headers)
df_tracks.head(3)
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0                                                 []            1
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#    duration_ms  explicit              external_ids  \
# 0       168120     False  {'isrc': 'GBAYE0601510'}
# 1       250160      True  {'isrc': 'USTB10250051'}
# 2       291440     False  {'isrc': 'ES5150103002'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/5e...
# 1  {'spotify': 'https://open.spotify.com/track/62...
# 2  {'spotify': 'https://open.spotify.com/track/0H...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/5e8uc7f0v5jp...  5e8uc7f0v5jpY5SF1emxHl
# 1  https://api.spotify.com/v1/tracks/62h3HmtlAmot...  62h3HmtlAmot4A9zwKVRSq
# 2  https://api.spotify.com/v1/tracks/0HmQkmfYXRPw...  0HmQkmfYXRPweIg1ycw1R8
#
#    is_local                                   name  popularity  \
# 0     False            Getting Better - Remastered           0
# 1     False  Mama, I'm in Love Wit a Gangsta - Mix          26
# 2     False                             Morena mía          67
#
#                                          preview_url  track_number   type  \
# 0                                               None             4  track
# 1  https://p.scdn.co/mp3-preview/7bfced09b64662fe...             3  track
# 2  https://p.scdn.co/mp3-preview/3164e42e1f32003f...             8  track
#
#                                     uri
# 0  spotify:track:5e8uc7f0v5jpY5SF1emxHl
# 1  spotify:track:62h3HmtlAmot4A9zwKVRSq
# 2  spotify:track:0HmQkmfYXRPweIg1ycw1R8

# %%
# create a dictionary of artist + track ids
artist_track_id_dict = {}
for i in range(len(df_tracks.artists)):
    x = df_tracks.artists[i][0]['id']
    y = df_tracks.id[i]
    artist_track_id_dict[x] = y
    
art_track_ids = pd.DataFrame([artist_track_id_dict]).transpose()
art_track_ids = art_track_ids.reset_index()
art_track_ids = art_track_ids.rename(columns={'index': 'artist_id', 0:'track_id'})
art_track_ids.head(3)
# Out:
#                 artist_id                track_id
# 0  3WrFJ7ztbogyGnTHbHJFl2  19aATlcb67bbIdjcMA0rOa
# 1  3y24n3XhZ96wgwRXjvS17T  5QMTmFY0KC0RfyRbQBEzzE
# 2  7mWCSSOYqm4E9mB7V4ot6S  2kpHaB82qVWd4ccYXGt5BE

# %%
art_ids = art_track_ids.artist_id.to_list()
df_artists = dc.song_attributes('artists/', art_ids, headers)
df_artists.head(3)
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/3...
# 1  {'spotify': 'https://open.spotify.com/artist/3...
# 2  {'spotify': 'https://open.spotify.com/artist/7...
#
#                            followers  \
# 0  {'href': None, 'total': 20981982}
# 1    {'href': None, 'total': 526798}
# 2   {'href': None, 'total': 1784540}
#
#                                               genres  \
# 0  [beatlesque, british invasion, classic rock, m...
# 1  [g funk, gangster rap, hip hop, rap, west coas...
# 2  [latin, latin pop, mexican pop, rock en espano...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/3WrFJ7ztbog...  3WrFJ7ztbogyGnTHbHJFl2
# 1  https://api.spotify.com/v1/artists/3y24n3XhZ96...  3y24n3XhZ96wgwRXjvS17T
# 2  https://api.spotify.com/v1/artists/7mWCSSOYqm4...  7mWCSSOYqm4E9mB7V4ot6S
#
#                                               images         name  popularity  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...  The Beatles          88
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...       Coolio          72
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Miguel Bosé          72
#
#      type                                    uri
# 0  artist  spotify:artist:3WrFJ7ztbogyGnTHbHJFl2
# 1  artist  spotify:artist:3y24n3XhZ96wgwRXjvS17T
# 2  artist  spotify:artist:7mWCSSOYqm4E9mB7V4ot6S

# %%
df_genres = df_artists[['id', 'genres']]
df_genres = df_genres.rename(columns={'id': 'artist_id'})
df_genres.head(3) #explode or 'df_stream.genres.apply(pd.Series)'?
# Out:
#                 artist_id                                             genres
# 0  3WrFJ7ztbogyGnTHbHJFl2  [beatlesque, british invasion, classic rock, m...
# 1  3y24n3XhZ96wgwRXjvS17T  [g funk, gangster rap, hip hop, rap, west coas...
# 2  7mWCSSOYqm4E9mB7V4ot6S  [latin, latin pop, mexican pop, rock en espano...

# %% [markdown]
# # 4) Consolidate All DataFrames

# %% [markdown]
# ### Merge all 4 dataframes: stream, features, track and genres.

# %%
df_stream = df_stream.merge(df_features, how='inner', 
                              left_on=['uri'],
                              right_on=['id'])

# %%
df_stream = df_stream.merge(art_track_ids, how='inner',
                           left_on=['id'],
                           right_on=['track_id'])

# %%
df_stream = df_stream.merge(df_genres, how='inner',
                           left_on='artist_id',
                           right_on='artist_id')

# %% [markdown]
# ### Return a final dataframe with the columns I will use.

# %%
df_stream = df_stream[['endTime','year','month','day','hour',
                       'artist','album','track','genres',
                       'minutesPlayed','id','danceability',
                       'energy','key','loudness','mode',
                       'speechiness','acousticness','instrumentalness',
                       'liveness','valence','tempo']]

# %%
df_stream.head(1)
# Out:
#               endTime  year  month  day  hour        artist       album  \
# 0 2019-08-29 16:31:00  2019      8   29    16  The Outfield  Super Hits
#
#        track                                             genres  \
# 0  Your Love  [album rock, mellow gold, new romantic, new wa...
#
#    minutesPlayed  ... energy  key  loudness  mode  speechiness  acousticness  \
# 0           3.61  ...  0.757    1    -7.868     0       0.0601         0.103
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001    0.0631    0.582  129.607
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Artist + Genres dataframe

# %%
df_genres = df_stream[['artist', 'genres']].explode('genres')
df_genres.head(1)
# Out:
#          artist      genres
# 0  The Outfield  album rock

# %% [markdown]
# # 5) Export New Databases

# %%
df_stream.to_csv('data/stream.csv')
df_genres.to_csv('data/genres.csv')
